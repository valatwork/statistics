# %% [markdown]
# ## Cross Validation with scikit-learn

# %% [markdown]
# 1. Cross-validation with `cross_val_score`
# 2. Cross-validation with `cross_validate`
# 3. Comparison with train/test split
# 4. Comparison with train/validation/test split

# %% [markdown]
# ### Cross Validation with cross_val_score

# %%
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('../project/data/another_advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis=1)
y = df['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(scores.mean())
# Out:
# np.float64(8.215396464543607)

# %%
model = Ridge(alpha=1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
abs(scores.mean())
# Out:
# np.float64(3.344839296530695)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.319021579428752

# %% [markdown]
# ### Cross Validation with cross_validate

# %% [markdown]
# The `cross_validate` function differs from `cross_val_score` in two ways:
#
# 1. It allows specifying multiple metrics for evaluation.
# 2. It returns a dictionary containing fit-times, score-times in addition to test score.

# %%
X = df.drop('sales', axis=1)
y = df['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_validate

# %%
scores = cross_validate(model,X_train,y_train,
                         scoring=['neg_mean_absolute_error','neg_mean_squared_error','max_error'],cv=5)

# %%
scores
# Out:
# {'fit_time': array([0.00168204, 0.00098491, 0.00116253, 0.00097632, 0.00091457]),
#  'score_time': array([0.00322151, 0.00122142, 0.00126171, 0.00159001, 0.00125647]),
#  'test_neg_mean_absolute_error': array([-2.31243044, -1.74653361, -2.56211701, -2.01873159, -2.27951906]),
#  'test_neg_mean_squared_error': array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#          -8.38562723]),
#  'test_max_error': array([ -6.44988486,  -5.58926073, -10.33914027,  -6.61950405,
#          -7.75578515])}

# %%
pd.DataFrame(scores)
# Out:
#    fit_time  score_time  test_neg_mean_absolute_error  \
# 0  0.001682    0.003222                     -2.312430
# 1  0.000985    0.001221                     -1.746534
# 2  0.001163    0.001262                     -2.562117
# 3  0.000976    0.001590                     -2.018732
# 4  0.000915    0.001256                     -2.279519
#
#    test_neg_mean_squared_error  test_max_error
# 0                    -9.325530       -6.449885
# 1                    -4.944962       -5.589261
# 2                   -11.396652      -10.339140
# 3                    -7.024211       -6.619504
# 4                    -8.385627       -7.755785

# %%
pd.DataFrame(scores).mean()
# Out:
# fit_time                        0.001144
# score_time                      0.001710
# test_neg_mean_absolute_error   -2.183866
# test_neg_mean_squared_error    -8.215396
# test_max_error                 -7.350715
# dtype: float64

# %%
model = Ridge(alpha=1)

# %%
scores = cross_validate(model,X_train,y_train,
                         scoring=['neg_mean_absolute_error','neg_mean_squared_error','max_error'],cv=5)

# %%
pd.DataFrame(scores).mean()
# Out:
# fit_time                        0.001940
# score_time                      0.001919
# test_neg_mean_absolute_error   -1.319685
# test_neg_mean_squared_error    -3.344839
# test_max_error                 -5.161145
# dtype: float64

# %% [markdown]
# What sklearn does is a simpler version the next two processes.

# %% [markdown]
# ### Train/Test Split

# %%
X = df.drop('sales', axis=1)
y = df['sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 7.34177578903413

# %%
model = Ridge(alpha=1)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.319021579428752

# %% [markdown]
# ### Train/Validation Test Split

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.3, random_state=101)
X_eval, X_test, y_eval, y_test = train_test_split(X_holdout, y_holdout, test_size=0.5, random_state=101)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_eval = scaler.transform(X_eval)
X_test = scaler.transform(X_test)

# %%
model = Ridge(alpha=1)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=1)

# %%
y_eval_pred = model.predict(X_eval)

# %%
mean_squared_error(y_eval, y_eval_pred)
# Out:
# 2.383783075056986

# %%
y_final_test_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_final_test_pred)
# Out:
# 2.2542600838005176

# %% [markdown]
# ## Grid Search

# %% [markdown]
# A grid search is a way of training and validating a model on every possible combination of multiple hyperparameters (provided as a dictionary) to find the best combination.
#
# Sci-kit learn provides a way to do this with the `GridSearchCV` class.

# %%
X = df.drop('sales',axis=1)
y = df['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet

# %%
base_elastic_model = ElasticNet()

# %%
param_grid = {'alpha':[0.1,1,5,10,50,100],
              'l1_ratio':[.1, .5, .7, .9, .95, .99, 1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_elastic_model,
                          param_grid=param_grid,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.1, 1, 5, 10, 50, 100],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]},
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# The results can be accessed using either `best_estimator_` or `best_params_` attributes.

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %% [markdown]
# All the combinations can be accessed using the `cv_results_` attribute:

# %%
pd.DataFrame(grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.001916      0.000937         0.000938        0.000326          0.1
# 1        0.001655      0.000440         0.001051        0.000196          0.1
# 2        0.001231      0.000197         0.000804        0.000338          0.1
# 3        0.001249      0.000464         0.000605        0.000089          0.1
# 4        0.000995      0.000112         0.000703        0.000241          0.1
# 5        0.001001      0.000121         0.000568        0.000054          0.1
# 6        0.001343      0.000246         0.000785        0.000159          0.1
# 7        0.001052      0.000203         0.000576        0.000027          1.0
# 8        0.001334      0.000272         0.000726        0.000191          1.0
# 9        0.001318      0.000441         0.000608        0.000070          1.0
# 10       0.000975      0.000061         0.000676        0.000180          1.0
# ...

# %% [markdown]
# The grid search model can be used to predict on the test set:

# %%
y_pred = grid_model.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.387342642087474
